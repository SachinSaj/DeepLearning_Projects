# %%
import pytesseract as py
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %%
img_to_ocr = cv2.imread('Desktop//car.webp')

# %%
plt.imshow(pre_img)
print(pre_img.shape)
# Out:
# (452, 602)

# %%
pre_img = cv2.cvtColor(img_to_ocr,cv2.COLOR_BGR2GRAY)
pre_img = cv2.threshold(pre_img,0,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
pre_img = cv2.medianBlur(pre_img,3)

# %%
cv2.imwrite('pre_img.jpg',pre_img)
# Out:
# True

# %%
pre_img = Image.open('pre_img.jpg')
plt.imshow(pre_img)

# %%
text = py.image_to_string(pre_img)

# %%
print(text)
# Out:
# —
#
# MHIZDE1433 |

# %%
plt.imshow(img_to_ocr)
